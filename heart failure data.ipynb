# %%
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\BIJOY\\Downloads\\heart_failure_clinical_records_dataset.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info
# Out:
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
data.shape
# Out:
# (299, 13)

# %%
data.describe() #descriptive statistics
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data= data.drop_duplicates()
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.isnull()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
data.notnull()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    True     True                      True      True               True
# 1    True     True                      True      True               True
# 2    True     True                      True      True               True
# 3    True     True                      True      True               True
# 4    True     True                      True      True               True
# ..    ...      ...                       ...       ...                ...
# 294  True     True                      True      True               True
# 295  True     True                      True      True               True
# 296  True     True                      True      True               True
# 297  True     True                      True      True               True
# 298  True     True                      True      True               True
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium   sex  \
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data2= data.fillna(value=0)
data2
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data2= data.fillna(value=0)
data2
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data3= data.fillna(method='pad')
data3
# Out:
# C:\Users\BIJOY\AppData\Local\Temp\ipykernel_10496\2695276835.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3= data.fillna(method='pad')
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# ...

# %%
#filling null values with the next value
data4= data.fillna(method='bfill')
data4
# Out:
# C:\Users\BIJOY\AppData\Local\Temp\ipykernel_10496\3305852866.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data4= data.fillna(method='bfill')
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#detect the outliers using IQR
data2.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data2.drop(['age'], axis=1, inplace=True)
data2.columns
# Out:
# Index(['anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction',
#        'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium',
#        'sex', 'smoking', 'time', 'DEATH_EVENT'],
#       dtype='object')

# %%
Q1= data2.quantile(0.25)
Q2= data2.quantile(0.75)
IQR=Q2-Q1
print(IQR)
# Out:
# anaemia                         1.0
# creatinine_phosphokinase      465.5
# diabetes                        1.0
# ejection_fraction              15.0
# high_blood_pressure             1.0
# platelets                   91000.0
# serum_creatinine                0.5
# serum_sodium                    6.0
# sex                             1.0
# smoking                         1.0
# time                          130.0
# DEATH_EVENT                     1.0
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q2+1.5*IQR))).any(axis=1)]
data2
# Out:
#      anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0          0                       582         0                 20
# 2          0                       146         0                 20
# 3          1                       111         0                 20
# 5          1                        47         0                 40
# 6          1                       246         0                 15
# ..       ...                       ...       ...                ...
# 291        0                       320         0                 35
# 292        0                       190         1                 38
# 293        1                       103         1                 35
# 294        0                        61         1                 38
# 298        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1   265000.0               1.9           130    1
# ...

# %%
data2.describe()
# Out:
#          anaemia  creatinine_phosphokinase    diabetes  ejection_fraction  \
# count  224.00000                224.000000  224.000000         224.000000
# mean     0.46875                336.941964    0.419643          38.178571
# std      0.50014                279.521085    0.494606          11.710801
# min      0.00000                 30.000000    0.000000          14.000000
# 25%      0.00000                114.500000    0.000000          30.000000
# 50%      0.00000                212.000000    0.000000          38.000000
# 75%      1.00000                582.000000    1.000000          45.000000
# max      1.00000               1202.000000    1.000000          65.000000
#
#        high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# count           224.000000     224.000000        224.000000    224.000000
# mean              0.379464  255865.190045          1.128571    137.044643
# std               0.486340   67153.749051          0.327794      3.806740
# ...
